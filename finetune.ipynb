# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# !7z x '/content/drive/MyDrive/Datasets/Handel Waste Classification/cdw_coco.7z' -o/content/

# %%
# !rm -rf /content/datasets
# !rm -rf /content/models

# %% [markdown]
# # Get Dataset from Kaggle

# %%
# !pip install addict yapf hydra-core tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -q kaggle

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e76c239a-3e92-4429-b525-18d3b9f2a606" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e76c239a-3e92-4429-b525-18d3b9f2a606">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d anhnguyentranminh/cdw-coco-finetune
# Out:
# Dataset URL: https://www.kaggle.com/datasets/anhnguyentranminh/cdw-coco-finetune
# License(s): unknown
# ...
# 100% 1.20M/1.20M [00:00<00:00, 103MB/s]

# %%
# !kaggle datasets download -d anhnguyentranminh/waste-cdw-green-waste
# Out:
# Dataset URL: https://www.kaggle.com/datasets/anhnguyentranminh/waste-cdw-green-waste
# License(s): unknown
# ...
# 100% 3.34G/3.34G [00:43<00:00, 82.7MB/s]

# %%
# !unzip cdw-coco-finetune.zip
# Out:
# Archive:  cdw-coco-finetune.zip
#   inflating: README.md
#   inflating: __init__.py
#   inflating: configs/demo.yaml
#   inflating: configs/sam2.1/sam2.1_hiera_l.yaml
#   inflating: configs/sam2.1/sam2.1_hiera_s.yaml
#   inflating: configs/train.yaml
#   inflating: configs/train_small.yaml
#   inflating: datasets/__init__.py
#   inflating: datasets/datasets.py
#   inflating: datasets/image_folder.py
#   inflating: datasets/transform_custom.py
#   inflating: datasets/wrappers.py
#   inflating: demo.py
#   inflating: eval_iou.py
#   inflating: finetune.py
#   inflating: mmcv/__init__.py
#   inflating: mmcv/arraymisc/__init__.py
#   inflating: mmcv/arraymisc/quantization.py
#   inflating: mmcv/cnn/__init__.py
#   inflating: mmcv/cnn/alexnet.py
#   inflating: mmcv/cnn/bricks/__init__.py
#   inflating: mmcv/cnn/bricks/activation.py
#   inflating: mmcv/cnn/bricks/context_block.py
#   inflating: mmcv/cnn/bricks/conv.py
#   inflating: mmcv/cnn/bricks/conv2d_adaptive_padding.py
# ...

# %%
# !unzip waste-cdw-green-waste.zip -d ./cdw_coco
# Out:
# Archive:  waste-cdw-green-waste.zip
#   inflating: ./cdw_coco/annotations.json
#   inflating: ./cdw_coco/annotations/instances_test.json
#   inflating: ./cdw_coco/annotations/instances_train.json
#   inflating: ./cdw_coco/annotations/instances_val.json
#   inflating: ./cdw_coco/images/0b0a9780-b3b9-11f0-8523-a2385bb6bc5a_7602761_original_20251028044606-1_3_pickup_reported_1_jpg.rf.4ddb920d14254e77e00daaf38dd4428a.jpg
#   inflating: ./cdw_coco/images/1000_F_170643224_IcD0KsfEPXilYcmWTISqEZHhWe9RFyIO_jpg.rf.82a532d1694d57790e052d39899be204.jpg
#   inflating: ./cdw_coco/images/1000_F_684850320_n0ivhvZmCdkn1Kf5tmcaGV4RpXDvbgpn_jpg.rf.cd240295f79453200bdc5a534113a665.jpg
#   inflating: ./cdw_coco/images/10591273025586_jpg.rf.f40e24aede228dfde2de3c8b845872ff.jpg
#   inflating: ./cdw_coco/images/11294f76f1514efb6c5943a61f38f9aa_jpg.rf.72f2d5800d710a2793ee16bfb61f1b25.jpg
#   inflating: ./cdw_coco/images/1_vm6fss5pFZ2q_lirp6JHjw_jpg.rf.b3f35dcb9d22cda17ef6396ec67056e3.jpg
# ...

# %%
# !wget -P /content/pretrained https://huggingface.co/facebook/sam2.1-hiera-large/resolve/main/sam2.1_hiera_large.pt
# Out:
# --2026-03-25 07:31:08--  https://huggingface.co/facebook/sam2.1-hiera-large/resolve/main/sam2.1_hiera_large.pt
# Resolving huggingface.co (huggingface.co)... 3.170.185.25, 3.170.185.33, 3.170.185.35, ...
# Connecting to huggingface.co (huggingface.co)|3.170.185.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !git clone https://github.com/DianiSirimewan/SAM2-Adapter-CDW.git /content/temp
# Out:
# Cloning into '/content/temp'...
# remote: Enumerating objects: 560, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 560 (delta 38), reused 12 (delta 12), pack-reused 505 (from 2)
# Receiving objects: 100% (560/560), 591.19 KiB | 12.58 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
# !rsync -a /content/temp/ /content/

# %%
# !python finetune.py
# Out:
# /content/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# [prepare] Splits already exist at cdw_coco  (use --force-prepare to redo).
# Device: cuda:0  |  distributed: False
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# [train] 10 classes (incl. background):
#   JSON cat_id=1 -> class_idx=1  (concrete_bricks_tiles)
#   JSON cat_id=2 -> class_idx=2  (soils)
#   JSON cat_id=3 -> class_idx=3  (green_waste_timber)
#   JSON cat_id=4 -> class_idx=4  (metals_e_waste)
#   JSON cat_id=5 -> class_idx=5  (plastic)
#   JSON cat_id=6 -> class_idx=6  (cardboard)
#   JSON cat_id=7 -> class_idx=7  (plasterboard)
# ...

# %%
# !zip -r /content/green_waste.zip \
    /content/save/_train \
# Out:
# 	zip warning: name not matched: \
#   adding: content/save/_train/ (stored 0%)
#   adding: content/save/_train/model_epoch_best.pth (deflated 7%)
#   adding: content/save/_train/model_epoch_last.pth (deflated 7%)
#   adding: content/save/_train/tensorboard/ (stored 0%)
#   adding: content/save/_train/tensorboard/events.out.tfevents.1774428120.1c1dc18df2f0 (deflated 5%)
#   adding: content/save/_train/tensorboard/events.out.tfevents.1774429749.1c1dc18df2f0 (deflated 50%)
#   adding: content/save/_train/tensorboard/events.out.tfevents.1774428431.1c1dc18df2f0 (deflated 5%)
#   adding: content/save/_train/config.yaml (deflated 57%)
#   adding: content/save/_train/log.txt (deflated 89%)

# %%
# !python demo.py
# Out:
# [demo_cpu] Running on device: cpu
# /content/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# [demo_cpu] Loading weights from: /content/save/_train/model_epoch_best.pth
# [demo_cpu] Weights loaded OK
# [demo_cpu] Single-image demo -> /content/cdw_coco/images/0b0a9780-b3b9-11f0-8523-a2385bb6bc5a_7602761_original_20251028044606-1_3_pickup_reported_1_jpg.rf.4ddb920d14254e77e00daaf38dd4428a.jpg
# [demo_cpu] Original size : W=432  H=432
# [demo_cpu] Running inference on /content/cdw_coco/images/0b0a9780-b3b9-11f0-8523-a2385bb6bc5a_7602761_original_20251028044606-1_3_pickup_reported_1_jpg.rf.4ddb920d14254e77e00daaf38dd4428a.jpg ...
# ...
